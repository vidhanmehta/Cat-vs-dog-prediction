# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/cv2/__init__.py:181
#     176             if DEBUG: print("Extra Python code for", submodule, "is loaded")
#     178     if DEBUG: print('OpenCV loader: DONE')
# --> 181 bootstrap()
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/cv2/__init__.py:153, in bootstrap()
#     149 if DEBUG: print("Relink everything from native cv2 module to cv2 package")
#     151 py_module = sys.modules.pop("cv2")
# --> 153 native_module = importlib.import_module("cv2")
#     155 sys.modules["cv2"] = py_module
#     156 setattr(py_module, "_native", native_module)
#
# File /usr/local/anaconda3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# ...

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
import random
import os

# %%
import os
path, dirs, files = next(os.walk('./train'))
file_count = len(files)
print('Number of images: ', file_count)
# Out:
# Number of images:  25000

# %%
file_names = os.listdir('./train/')
print(file_names)
# Out:
# ['dog.8011.jpg', 'cat.5077.jpg', 'dog.7322.jpg', 'cat.2718.jpg', 'cat.10151.jpg', 'cat.3406.jpg', 'dog.1753.jpg', 'cat.4369.jpg', 'cat.7660.jpg', 'dog.5535.jpg', 'cat.8553.jpg', 'cat.9895.jpg', 'cat.1211.jpg', 'dog.3144.jpg', 'dog.775.jpg', 'dog.11102.jpg', 'cat.6218.jpg', 'dog.11664.jpg', 'dog.3622.jpg', 'cat.1577.jpg', 'cat.12020.jpg', 'dog.5253.jpg', 'cat.7106.jpg', 'cat.8235.jpg', 'cat.952.jpg', 'dog.9469.jpg', 'dog.1035.jpg', 'cat.3360.jpg', 'cat.11529.jpg', 'cat.10637.jpg', 'dog.6982.jpg', 'dog.8777.jpg', 'dog.7444.jpg', 'cat.5711.jpg', 'cat.946.jpg', 'cat.3374.jpg', 'dog.1021.jpg', 'dog.6996.jpg', 'cat.10623.jpg', 'dog.8763.jpg', 'cat.5705.jpg', 'dog.7450.jpg', 'dog.12379.jpg', 'dog.11670.jpg', 'dog.4159.jpg', 'cat.1563.jpg', 'dog.3636.jpg', 'cat.12034.jpg', 'dog.2528.jpg', 'cat.7112.jpg', 'dog.5247.jpg', 'cat.8221.jpg', 'dog.10208.jpg', 'dog.5521.jpg', 'cat.7674.jpg', 'cat.8547.jpg', 'cat.9881.jpg', 'dog.761.jpg', 'dog.3150.jpg', 'cat.1205.jpg', 'dog.11116.jpg', 'cat.9659.jpg
# ...

# %%
img = mpimg.imread('./train/dog.10308.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./train/cat.14.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
file_names = os.listdir('./train/')

for i in range(12497,12504):

  name = file_names[i] 
  print(name[0:3])
# Out:
# cat
# cat
# dog
# dog
# cat
# dog
# dog

# %%
file_names = os.listdir('./train/')

dog_count = 0
cat_count = 0

for img_file in file_names:

  name = img_file[0:3]

  if name == 'dog':
    dog_count += 1

  else:
    cat_count += 1

print('Number of dog images =', dog_count)
print('Number of cat images =', cat_count)
# Out:
# Number of dog images = 12500
# Number of cat images = 12500

# %%
original_folder = './train/'
resized_folder = './image resized/'

for i in range(12000,13001):

  filename = os.listdir(original_folder)[i]
  img_path = original_folder+filename

  img = Image.open(img_path)
  img = img.resize((224, 224))
  img = img.convert('RGB')

  newImgPath = resized_folder+filename
  img.save(newImgPath)

# %%
img = mpimg.imread('./image resized/dog.11.jpg')
imgplt = plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 img = mpimg.imread('./image resized/dog.11.jpg')
#       2 imgplt = plt.imshow(img)
#       3 plt.show()
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/matplotlib/image.py:1561, in imread(fname, format)
#    1554 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1555     # Pillow doesn't handle URLs directly.
#    1556     raise ValueError(
#    1557         "Please open the URL for reading and pass the "
#    1558         "result to Pillow, e.g. with "
#    1559         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1560         )
# -> 1561 with img_open(fname) as image:
#    1562     return (_pil_png_to_float_array(image)
#    1563             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1564             pil_to_array(image))
# ...

# %%
img = mpimg.imread('./image resized/cat.979.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
filenames = os.listdir('./image resized/')


labels = []

for i in range(1001):

  file_name = filenames[i]
  label = file_name[0:3]

  if label == 'dog':
    labels.append(1)

  else:
    labels.append(0)

# %%
print(filenames[498:503])
print(len(filenames))
# Out:
# ['cat.9944.jpg', 'cat.9950.jpg', 'cat.9788.jpg', 'cat.9789.jpg', 'cat.9951.jpg']
# 1969

# %%
print(labels[498:503])
print(len(labels))
# Out:
# [0, 0, 0, 0, 0]
# 1001

# %%
values, counts = np.unique(labels, return_counts=True)
print(values)
print(counts)
# Out:
# [0 1]
# [490 511]

# %%
import glob
import opencv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 import glob
# ----> 2 import opencv
#
# ModuleNotFoundError: No module named 'opencv'

# %%
image_directory = './image resized/'
image_extension = ['png', 'jpg']

files = []

[files.extend(glob.glob(image_directory + '*.' + e)) for e in image_extension]

dog_cat_images = np.asarray([cv2.imread(file) for file in files])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 8
#       4 files = []
#       6 [files.extend(glob.glob(image_directory + '*.' + e)) for e in image_extension]
# ----> 8 dog_cat_images = np.asarray([cv2.imread(file) for file in files])
#
# Cell In[35], line 8, in <listcomp>(.0)
#       4 files = []
#       6 [files.extend(glob.glob(image_directory + '*.' + e)) for e in image_extension]
# ----> 8 dog_cat_images = np.asarray([cv2.imread(file) for file in files])
#
# NameError: name 'cv2' is not defined

# %%
print(dog_cat_images)
# Out:
# [[[[ 48 107 133]
#    [ 50 108 137]
#    [ 52 109 140]
#    ...
#    [ 39  79 127]
#    [ 49  86 136]
#    [ 64 101 151]]
#
#   [[ 48 107 133]
#    [ 49 107 136]
#    [ 51 108 139]
#    ...
#    [ 66 106 155]
#    [ 68 105 155]
#    [ 73 110 160]]
#
#   [[ 50 107 133]
#    [ 51 107 136]
#    [ 53 108 139]
#    ...
#    [105 144 196]
#    [101 138 190]
#    [ 98 135 187]]
#
#   ...
#
#   [[ 47  83 107]
#    [ 47  82 108]
#    [ 45  81 111]
#    ...
#    [ 27  47  72]
#    [ 35  52  78]
#    [ 39  56  82]]
#
#   [[ 44  80 104]
#    [ 47  82 108]
#    [ 47  83 113]
#    ...
#    [ 28  45  71]
#    [ 29  47  70]
#    [ 31  49  72]]
#
#   [[ 45  81 105]
#    [ 49  84 110]
#    [ 47  83 113]
#    ...
#    [ 26  43  69]
#    [ 25  43  66]
#    [ 24  42  65]]]
#
#
#  [[[250 247 239]
#    [255 255 248]
#    [251 255 252]
#    ...
#    [ 24  24  24]
#    [ 22  22  22]
#    [ 19  19  19]]
#
#   [[255 252 247]
#    [254 254 248]
#    [241 248 243]
#    ...
#    [ 23  23  23]
#    [ 21  21  21]
# ...

# %%
import tensorflow as tf
import tensorflow_hub as hub
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 2
#       1 import tensorflow as tf
# ----> 2 import tensorflow_hub as hub
#
# ModuleNotFoundError: No module named 'tensorflow_hub'
